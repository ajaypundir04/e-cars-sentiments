# %%
# !git clone https://github.com/ajaypundir04/e-cars-sentiments.git
# Out:
# Cloning into 'e-cars-sentiments'...
# remote: Enumerating objects: 421, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 421 (delta 4), reused 9 (delta 4), pack-reused 399 (from 1)
# Receiving objects: 100% (421/421), 19.09 MiB | 16.84 MiB/s, done.
# Resolving deltas: 100% (200/200), done.

# %%
# !pwd
import os
os.chdir('/content/e-cars-sentiments')
# !pwd
# Out:
# /content
# /content/e-cars-sentiments

# %%
# !ls
# Out:
# articles.txt  __init__.py  README.md		   sentiment_anaylsis_flowchart.png  train.jsonl
# config.ini    output	   References.txt	   setup.py			     utils
# executor      prediction   requirements.txt	   stats			     valid.jsonl
# handler       processor    sentiment_analysis.png  survey.ini

# %%
# !git checkout transformer-application
# Out:
# Branch 'transformer-application' set up to track remote branch 'transformer-application' from 'origin'.
# Switched to a new branch 'transformer-application'

# %%
# !ls
# Out:
# algorithm.md		handler		requirements.txt		  train.jsonl
# articles.txt		__init__.py	SalesPrediction.png		  transformer
# classes.dot		output		sentiment-analysis.png		  utils
# classes.mmd		packages.dot	sentiment_analysis.png		  valid.jsonl
# cn_ft.otf		packages.mmd	sentiment_anaylsis_flowchart.png  Visualization.png
# config.ini		prediction	setup.py			  Workflow.png
# contexts_answers.json	processor	stats
# data-preprocessing.png	README.md	SurveyGeneration.png
# executor		References.txt	survey.ini

# %%
# !python -m executor.executor --mode=transformer --language=EN
# Out:
# 2025-03-02 09:42:10.464306: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740908530.641117     668 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740908530.679332     668 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-02 09:42:10.842893: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python -m executor.executor --mode=transformer --language=DE
# Out:
# 2025-03-02 09:57:52.600741: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740909472.880933    4422 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740909472.953644    4422 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-02 09:57:53.520701: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !pwd
# Out:
# /content/e-cars-sentiments

# %%
from transformer.data_loader import ElectricCarSentimentDataset
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-cased")
dataset = ElectricCarSentimentDataset("config.ini", tokenizer)

# %%
from transformer.sentiment_model import TransformerModel

# Create an instance of TransformerModel
model_instance = TransformerModel()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2025-03-02 00:00:04,624 - INFO - Initialized TransformerModel
# INFO:transformer.sentiment_model:Initialized TransformerModel

# %%
model_instance.fine_tune_model(dataset)
# Out:
# 2025-03-02 00:01:39,460 - INFO - Starting fine-tuning...
# INFO:__main__:Starting fine-tuning...
# /usr/local/lib/python3.11/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1/3: 100%|██████████| 72/72 [06:00<00:00,  5.01s/it]
# 2025-03-02 00:07:40,297 - INFO - Epoch 1: Training Loss = 0.8067
# INFO:__main__:Epoch 1: Training Loss = 0.8067
# Epoch 2/3: 100%|██████████| 72/72 [05:58<00:00,  4.98s/it]
# 2025-03-02 00:13:38,636 - INFO - Epoch 2: Training Loss = 0.4129
# INFO:__main__:Epoch 2: Training Loss = 0.4129
# Epoch 3/3: 100%|██████████| 72/72 [05:58<00:00,  4.98s/it]
# 2025-03-02 00:19:37,064 - INFO - Epoch 3: Training Loss = 0.2451
# INFO:__main__:Epoch 3: Training Loss = 0.2451
# ...

# %%
model_instance = TransformerModel()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2025-03-02 00:01:18,401 - INFO - Initialized TransformerModel It.
# INFO:__main__:Initialized TransformerModel It.

# %%
from transformer.data_loader import ElectricCarSentimentDataset
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-cased")
dataset = ElectricCarSentimentDataset("config.ini", tokenizer)

# %%
from transformer.sentiment_model import TransformerModel

# Create an instance of TransformerModel
model_instance = TransformerModel()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2025-03-01 23:56:09,670 - INFO - Initialized TransformerModel
# INFO:transformer.sentiment_model:Initialized TransformerModel

# %%
# !git pull -r
# Out:
# Updating c9fbc5a..b8b9a47
# Fast-forward
#  transformer/data_loader.py     | 31 ++++++++++++++------------
#  transformer/sentiment_model.py | 74 ++++++++++++++++++++++++++++++++++++++++----------------------
#  2 files changed, 65 insertions(+), 40 deletions(-)

# %%
os.chdir('/content/e-cars-sentiments/e_car_sentiment_model')

# %%
# !ls
# Out:
# config.json	   special_tokens_map.json  tokenizer.json
# model.safetensors  tokenizer_config.json    vocab.txt

# %%
os.chdir('/content')

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# ...

# %%
# !huggingface-cli repo create e_car_sentiment_model
# Out:
# git version 2.34.1
# git-lfs/3.0.2 (GitHub; linux amd64; go 1.18.1)
#
# You are about to create ajay-pundir/e_car_sentiment_model
# Proceed? [Y/n] y
#
# Your repo now lives at:
#   https://huggingface.co/ajay-pundir/e_car_sentiment_model
#
# You can clone it locally with the command below, and commit/push as usual.
#
#   git clone https://huggingface.co/ajay-pundir/e_car_sentiment_model

# %%
# !pwd
# Out:
# /content/e-cars-sentiments

# %%
# !git clone https://huggingface.co/ajay-pundir/e_car_sentiment_model
# !cd e_car_sentiment_model
# Out:
# Cloning into 'e_car_sentiment_model'...
# remote: Enumerating objects: 3, done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 3 (from 1)
# Unpacking objects: 100% (3/3), 1.06 KiB | 1.06 MiB/s, done.

# %%
# !cp -r /content/e-cars-sentiments/e_car_sentiment_model/ /content/e-cars-sentiments/e_car_sentiment_model/
# Out:
# cp: cannot copy a directory, '/content/e-cars-sentiments/e_car_sentiment_model/', into itself, '/content/e-cars-sentiments/e_car_sentiment_model/e_car_sentiment_model'

# %%
os.chdir('/content/e_car_sentiment_model/e_car_sentiment_model')

# %%
# !cp -r ../e-cars-sentiments/e_car_sentiment_model/ .

# %%
# !git add .
# !git commit -m "Upload fine-tuned electric car sentiment model"
# !git push
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://huggingface.co': No such device or address

# %%
# !git config --global user.email "ajaysinghpundir70@gmail.com"

# %%
! git config --global user.name "ajay-pundir"

# %%
# !ls
# Out:
# config.json	       model.safetensors	tokenizer_config.json  vocab.txt
# e_car_sentiment_model  special_tokens_map.json	tokenizer.json

# %%
# !pip install huggingface_hub

from huggingface_hub import notebook_login

notebook_login()
